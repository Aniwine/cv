# %% [markdown]
# ##### 构建数据集

# %%
import numpy as np
from mmcv.transforms import to_tensor
from torch.utils.data import random_split 
from torchvision.datasets import MNIST
from mmengine.dataset import BaseDataset

class MnistDataset(BaseDataset):
    def __init__(self,data_root,pipeline,test_mode=False):
        if test_mode:#如果是训练模式
            mnist_full=MNIST(data_root,train=True,download=True)
            self.mnist_dataset,_=random_split(mnist_full,[55000,5000])
        else:
            self.mnist_dataset=MNIST(data_root,train=False,download=True)
        super().__init__(data_root=data_root,pipeline=pipeline,test_mode=test_mode)

    @staticmethod
    def totensor(img):
        if len(img.shape)<3:#单通道图像
            img=np.expand_dims(img,axis=-1)
        img=np.ascontiguousarray(img.transpose(2,0,1))#H,W,C->C,H,W;并使用内存连续的张量
        return to_tensor(img)
    
    def load_data_list(self):
        return [dict(inputs=self.totensor(np.array(x[0]))) for x in self.mnist_dataset]

# %%
dataset=MnistDataset('./data/',[])

# %%
import os
import torch
from mmengine.runner import Runner

NUM_WORKERS=int(os.cpu_count()/2)
BATCH_SIZE=256 if torch.cuda.is_available() else 64

train_dataloader=dict(
    num_workers=NUM_WORKERS,
    batch_size=BATCH_SIZE,
    persistent_workers=True,
    sampler=dict(type='DefaultSampler', shuffle=True),
    dataset=dataset
)

train_dataloader=Runner.build_dataloader(dataloader=train_dataloader)

# %%
import torch.nn as nn

#生成式网络
class Generator(nn.Module):
    def __init__(self, noise_size, img_shape):
        super().__init__()
        self.img_shape = img_shape
        self.noise_size = noise_size

        def block(in_feat, out_feat, normalize=True):
            layers = [nn.Linear(in_feat, out_feat)]
            if normalize:
                layers.append(nn.BatchNorm1d(out_feat, 0.8))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
            return layers

        self.model = nn.Sequential(
            *block(noise_size, 128, normalize=False),
            *block(128, 256),
            *block(256, 512),
            *block(512, 1024),
            nn.Linear(1024, int(np.prod(img_shape))),
            nn.Tanh(),
        )

    def forward(self, z):
        img = self.model(z)
        img = img.view(img.size(0), *self.img_shape)
        return img

#判别式网络
class Discriminator(nn.Module):
    def __init__(self, img_shape):
        super().__init__()

        self.model = nn.Sequential(
            nn.Linear(int(np.prod(img_shape)), 512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(256, 1),
            nn.Sigmoid(),
        )

    def forward(self, img):
        img_flat = img.view(img.size(0), -1)
        validity = self.model(img_flat)

        return validity

# %%
generator = Generator(100, (1, 28, 28))
discriminator = Discriminator((1, 28, 28))

# %%
from mmengine.model import ImgDataPreprocessor
data_preprocessor=ImgDataPreprocessor(mean=([127.5]),std=([127.5]))

# %%
#GAN模型
import torch.nn.functional as F
from mmengine.model import BaseModel

def set_requires_grad(net,requires_grad=False):
    """锁定网络权重梯度"""
    if not isinstance(net,list):
        net=[net]
    for i in net:
        if i is not None:
            for param in i.parameters():
                param.requires_grad=requires_grad

class GAN(BaseModel):
    def __init__(self,generator,discriminator,noise_size,data_preprocessor):
        super().__init__(data_preprocessor=data_preprocessor)

        assert generator.noise_size==noise_size
        self.generator=generator
        self.discriminator=discriminator
        self.noise_size=noise_size

    def train_step(self,data,optim_wrapper):
        inputs_dict=data_preprocessor(data,True)
        #训练判别器
        disc_optimizer_wrapper=optim_wrapper['discriminator']
        with disc_optimizer_wrapper.optim_context(self.discriminator):
            log_vars=self.train_discriminator(inputs_dict,disc_optimizer_wrapper)

        #训练生成器
        set_requires_grad(self.discriminator,False)
        gen_optimzer_wrapper=optim_wrapper['generator']
        with gen_optimzer_wrapper.optim_context(self.generator):
            log_vars_gen=self.train_generator(inputs_dict,gen_optimzer_wrapper)

        set_requires_grad(self.discriminator,True)
        log_vars.update(log_vars_gen)

        return log_vars

    def forward(self,batch_inputs,data_samples=None,mode=None):
        return self.generator(batch_inputs)

    def train_discriminator(self,inputs,optimizer_wrapper):
        real_imgs=inputs['inputs']
        z=torch.randn((real_imgs.shape[0],self.noise_size)).type_as(real_imgs)
        with torch.no_grad():
            fake_imgs=self.generator(z)
        disc_pred_fake=self.discriminator(fake_imgs)
        disc_pred_real=self.discriminator(real_imgs)

        parsed_losses,log_vars=self.disc_loss(disc_pred_fake,disc_pred_real)
        optimizer_wrapper.update_params(parsed_losses)

        return log_vars

    def train_generator(self,inputs,optimizer_wrapper):
        real_imgs=inputs['inputs']
        z=torch.randn((real_imgs.shape[0],self.noise_size)).type_as(real_imgs)
        fake_imgs=self.generator(z)
        disc_pred_fake=self.discriminator(fake_imgs)
        parsed_losses,log_vars=self.gen_loss(disc_pred_fake)
        optimizer_wrapper.update_params(parsed_losses)

        return log_vars
    
    def disc_loss(self,disc_pred_fake,disc_pred_real):
        losses_dict=dict()
        losses_dict['loss_disc_fake']=F.binary_cross_entropy(disc_pred_fake,
                                    0.*torch.ones_like(disc_pred_fake))
        losses_dict['loss_disc_real']=F.binary_cross_entropy(disc_pred_real,
                                    1.*torch.ones_like(disc_pred_real))
        loss,log_vars=self.parse_losses(losses_dict)
        return loss,log_vars
    
    def gen_loss(self,disc_pred_fake):
        losses_dict=dict()
        losses_dict['loss_gen']=F.binary_cross_entropy(disc_pred_fake,
                                    1.*torch.ones_like(disc_pred_fake))
        
        loss,log_vars=self.parse_losses(losses_dict)

        return loss,log_vars

# %%
model = GAN(generator, discriminator, 100, data_preprocessor)

# %% [markdown]
# ##### 构建优化器

# %%
from mmengine.optim import OptimWrapper,OptimWrapperDict

g_optim=torch.optim.Adam(generator.parameters(),lr=1e-4,betas=(0.5,0.999))
g_optimizer_wrapper=OptimWrapper(g_optim)

d_optim=torch.optim.Adam(discriminator.parameters(),lr=1e-4,betas=(0.5,0.999))
d_optimizer_wrapper=OptimWrapper(d_optim)

optimizer_wrapper=OptimWrapperDict(generator=g_optimizer_wrapper,discriminator=d_optimizer_wrapper)

# %%
#训练
from mmengine.runner import Runner
train_cfg=dict(by_epoch=True,max_epochs=220)
runner=Runner(
    model=model,
    work_dir='./work_dir/gan',
    train_cfg=train_cfg,
    train_dataloader=train_dataloader,
    optim_wrapper=optimizer_wrapper
)


runner.train()
# Out:
# 08/10 06:48:27 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.4 | packaged by conda-forge | (main, Mar 24 2022, 17:39:04) [GCC 10.3.0]
#     CUDA available: True
#     numpy_random_seed: 802111463
#     GPU 0,1: GeForce GTX 1080
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 10.2, V10.2.8
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.12.0+cu102
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 10.2
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70
#   - CuDNN 7.6.5
#   - Magma 2.5.2
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=10.2, CUDNN_VERSION=7.6.5, CXX_COMPILER=/opt/rh/devtoolset-7/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.12.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=OFF, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.13.0+cu102
#     OpenCV: 4.8.0
#     MMEngine: 0.8.2
#
# Runtime environment:
#     dist_cfg: {'backend': 'nccl'}
#     seed: 802111463
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 08/10 06:48:27 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 08/10 06:48:27 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 08/10 06:48:27 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 08/10 06:48:27 - mmengine - INFO - Checkpoints will be saved to /volume/opemmmlab/mmengine/work_dir/gan.
# 08/10 06:48:29 - mmengine - INFO - Epoch(train)   [1][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:21:58  time: 0.1500  data_time: 0.1218  memory: 44  loss: 0.7027  loss_disc_fake: 0.6837  loss_disc_real: 0.3964  loss_gen: 0.7027
# 08/10 06:48:30 - mmengine - INFO - Epoch(train)   [1][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:17:02  time: 0.0829  data_time: 0.0623  memory: 44  loss: 0.6686  loss_disc_fake: 0.7194  loss_disc_real: 0.0717  loss_gen: 0.6686
# 08/10 06:48:30 - mmengine - INFO - Epoch(train)   [1][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:15:08  time: 0.0780  data_time: 0.0570  memory: 44  loss: 0.6105  loss_disc_fake: 0.7922  loss_disc_real: 0.0350  loss_gen: 0.6105
# 08/10 06:48:31 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:48:31 - mmengine - INFO - Epoch(train)   [1][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:14:01  time: 0.0734  data_time: 0.0518  memory: 44  loss: 0.5943  loss_disc_fake: 0.8221  loss_disc_real: 0.0677  loss_gen: 0.5943
# 08/10 06:48:31 - mmengine - INFO - Saving checkpoint at 1 epochs
# 08/10 06:48:31 - mmengine - WARNING - `save_param_scheduler` is True but `self.param_schedulers` is None, so skip saving parameter schedulers
# 08/10 06:48:32 - mmengine - INFO - Epoch(train)   [2][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:13:49  time: 0.0898  data_time: 0.0702  memory: 44  loss: 0.5899  loss_disc_fake: 0.8385  loss_disc_real: 0.1385  loss_gen: 0.5899
# 08/10 06:48:33 - mmengine - INFO - Epoch(train)   [2][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:13:13  time: 0.0707  data_time: 0.0488  memory: 44  loss: 0.5823  loss_disc_fake: 0.8708  loss_disc_real: 0.2277  loss_gen: 0.5823
# 08/10 06:48:34 - mmengine - INFO - Epoch(train)   [2][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:12:58  time: 0.0794  data_time: 0.0608  memory: 44  loss: 0.5858  loss_disc_fake: 0.8728  loss_disc_real: 0.3089  loss_gen: 0.5858
# 08/10 06:48:34 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:48:34 - mmengine - INFO - Epoch(train)   [2][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:12:30  time: 0.0646  data_time: 0.0480  memory: 44  loss: 0.5945  loss_disc_fake: 0.8739  loss_disc_real: 0.3845  loss_gen: 0.5945
# 08/10 06:48:34 - mmengine - INFO - Saving checkpoint at 2 epochs
# 08/10 06:48:35 - mmengine - INFO - Epoch(train)   [3][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:12:35  time: 0.0921  data_time: 0.0728  memory: 44  loss: 0.6195  loss_disc_fake: 0.8338  loss_disc_real: 0.4379  loss_gen: 0.6195
# 08/10 06:48:36 - mmengine - INFO - Epoch(train)   [3][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:12:17  time: 0.0675  data_time: 0.0476  memory: 44  loss: 0.6503  loss_disc_fake: 0.8092  loss_disc_real: 0.4530  loss_gen: 0.6503
# 08/10 06:48:37 - mmengine - INFO - Epoch(train)   [3][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:12:04  time: 0.0691  data_time: 0.0490  memory: 44  loss: 0.6933  loss_disc_fake: 0.7636  loss_disc_real: 0.4540  loss_gen: 0.6933
# 08/10 06:48:37 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:48:37 - mmengine - INFO - Epoch(train)   [3][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:11:52  time: 0.0683  data_time: 0.0494  memory: 44  loss: 0.7162  loss_disc_fake: 0.7656  loss_disc_real: 0.4521  loss_gen: 0.7162
# 08/10 06:48:37 - mmengine - INFO - Saving checkpoint at 3 epochs
# 08/10 06:48:38 - mmengine - INFO - Epoch(train)   [4][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:11:55  time: 0.0869  data_time: 0.0675  memory: 44  loss: 0.7067  loss_disc_fake: 0.7585  loss_disc_real: 0.4652  loss_gen: 0.7067
# 08/10 06:48:39 - mmengine - INFO - Epoch(train)   [4][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:11:50  time: 0.0767  data_time: 0.0488  memory: 44  loss: 0.7447  loss_disc_fake: 0.7373  loss_disc_real: 0.4321  loss_gen: 0.7447
# 08/10 06:48:40 - mmengine - INFO - Epoch(train)   [4][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:12:10  time: 0.1181  data_time: 0.0874  memory: 44  loss: 0.7904  loss_disc_fake: 0.7170  loss_disc_real: 0.4395  loss_gen: 0.7904
# 08/10 06:48:41 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:48:41 - mmengine - INFO - Epoch(train)   [4][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:12:17  time: 0.0974  data_time: 0.0713  memory: 44  loss: 0.7907  loss_disc_fake: 0.7371  loss_disc_real: 0.4565  loss_gen: 0.7907
# 08/10 06:48:41 - mmengine - INFO - Saving checkpoint at 4 epochs
# 08/10 06:48:42 - mmengine - INFO - Epoch(train)   [5][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:12:30  time: 0.1144  data_time: 0.0870  memory: 44  loss: 0.7983  loss_disc_fake: 0.7350  loss_disc_real: 0.4534  loss_gen: 0.7983
# 08/10 06:48:43 - mmengine - INFO - Epoch(train)   [5][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:12:27  time: 0.0827  data_time: 0.0615  memory: 44  loss: 0.8278  loss_disc_fake: 0.7301  loss_disc_real: 0.4422  loss_gen: 0.8278
# 08/10 06:48:44 - mmengine - INFO - Epoch(train)   [5][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:12:22  time: 0.0768  data_time: 0.0556  memory: 44  loss: 0.8644  loss_disc_fake: 0.7137  loss_disc_real: 0.4188  loss_gen: 0.8644
# 08/10 06:48:45 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:48:45 - mmengine - INFO - Epoch(train)   [5][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:12:12  time: 0.0659  data_time: 0.0439  memory: 44  loss: 0.8564  loss_disc_fake: 0.7272  loss_disc_real: 0.4058  loss_gen: 0.8564
# 08/10 06:48:45 - mmengine - INFO - Saving checkpoint at 5 epochs
# 08/10 06:48:45 - mmengine - INFO - Epoch(train)   [6][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:12:10  time: 0.0810  data_time: 0.0598  memory: 44  loss: 0.8843  loss_disc_fake: 0.6973  loss_disc_real: 0.3870  loss_gen: 0.8843
# 08/10 06:48:46 - mmengine - INFO - Epoch(train)   [6][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:12:03  time: 0.0705  data_time: 0.0509  memory: 44  loss: 0.9579  loss_disc_fake: 0.6687  loss_disc_real: 0.3707  loss_gen: 0.9579
# 08/10 06:48:47 - mmengine - INFO - Epoch(train)   [6][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:11:57  time: 0.0686  data_time: 0.0493  memory: 44  loss: 0.9016  loss_disc_fake: 0.6906  loss_disc_real: 0.3980  loss_gen: 0.9016
# 08/10 06:48:47 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:48:47 - mmengine - INFO - Epoch(train)   [6][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:11:47  time: 0.0600  data_time: 0.0435  memory: 44  loss: 0.9637  loss_disc_fake: 0.6798  loss_disc_real: 0.3764  loss_gen: 0.9637
# 08/10 06:48:47 - mmengine - INFO - Saving checkpoint at 6 epochs
# 08/10 06:48:48 - mmengine - INFO - Epoch(train)   [7][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:11:46  time: 0.0799  data_time: 0.0616  memory: 44  loss: 1.0370  loss_disc_fake: 0.6222  loss_disc_real: 0.3551  loss_gen: 1.0370
# 08/10 06:48:49 - mmengine - INFO - Epoch(train)   [7][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:11:40  time: 0.0676  data_time: 0.0490  memory: 44  loss: 1.0100  loss_disc_fake: 0.6604  loss_disc_real: 0.3783  loss_gen: 1.0100
# 08/10 06:48:50 - mmengine - INFO - Epoch(train)   [7][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:11:37  time: 0.0768  data_time: 0.0558  memory: 44  loss: 1.0522  loss_disc_fake: 0.6307  loss_disc_real: 0.3563  loss_gen: 1.0522
# 08/10 06:48:50 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:48:50 - mmengine - INFO - Epoch(train)   [7][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:11:30  time: 0.0592  data_time: 0.0427  memory: 44  loss: 0.9646  loss_disc_fake: 0.6811  loss_disc_real: 0.3542  loss_gen: 0.9646
# 08/10 06:48:50 - mmengine - INFO - Saving checkpoint at 7 epochs
# 08/10 06:48:51 - mmengine - INFO - Epoch(train)   [8][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:11:30  time: 0.0844  data_time: 0.0659  memory: 44  loss: 0.9612  loss_disc_fake: 0.6700  loss_disc_real: 0.3361  loss_gen: 0.9612
# 08/10 06:48:52 - mmengine - INFO - Epoch(train)   [8][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:11:23  time: 0.0580  data_time: 0.0382  memory: 44  loss: 0.9354  loss_disc_fake: 0.6764  loss_disc_real: 0.3506  loss_gen: 0.9354
# 08/10 06:48:52 - mmengine - INFO - Epoch(train)   [8][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:11:19  time: 0.0713  data_time: 0.0514  memory: 44  loss: 0.9953  loss_disc_fake: 0.6461  loss_disc_real: 0.3388  loss_gen: 0.9953
# 08/10 06:48:53 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:48:53 - mmengine - INFO - Epoch(train)   [8][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:11:13  time: 0.0603  data_time: 0.0439  memory: 44  loss: 0.8968  loss_disc_fake: 0.6994  loss_disc_real: 0.4197  loss_gen: 0.8968
# 08/10 06:48:53 - mmengine - INFO - Saving checkpoint at 8 epochs
# 08/10 06:48:54 - mmengine - INFO - Epoch(train)   [9][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:11:12  time: 0.0791  data_time: 0.0597  memory: 44  loss: 0.9720  loss_disc_fake: 0.6670  loss_disc_real: 0.4389  loss_gen: 0.9720
# 08/10 06:48:55 - mmengine - INFO - Epoch(train)   [9][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:11:11  time: 0.0779  data_time: 0.0501  memory: 44  loss: 1.0186  loss_disc_fake: 0.6625  loss_disc_real: 0.4422  loss_gen: 1.0186
# 08/10 06:48:55 - mmengine - INFO - Epoch(train)   [9][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:11:08  time: 0.0717  data_time: 0.0529  memory: 44  loss: 1.0456  loss_disc_fake: 0.6533  loss_disc_real: 0.4418  loss_gen: 1.0456
# 08/10 06:48:56 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:48:56 - mmengine - INFO - Epoch(train)   [9][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:11:03  time: 0.0594  data_time: 0.0428  memory: 44  loss: 1.0624  loss_disc_fake: 0.6509  loss_disc_real: 0.4472  loss_gen: 1.0624
# 08/10 06:48:56 - mmengine - INFO - Saving checkpoint at 9 epochs
# 08/10 06:48:57 - mmengine - INFO - Epoch(train)  [10][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:11:02  time: 0.0797  data_time: 0.0599  memory: 44  loss: 1.0364  loss_disc_fake: 0.6602  loss_disc_real: 0.4558  loss_gen: 1.0364
# 08/10 06:48:57 - mmengine - INFO - Epoch(train)  [10][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:11:01  time: 0.0739  data_time: 0.0535  memory: 44  loss: 1.0515  loss_disc_fake: 0.6463  loss_disc_real: 0.4163  loss_gen: 1.0515
# 08/10 06:48:58 - mmengine - INFO - Epoch(train)  [10][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:58  time: 0.0706  data_time: 0.0487  memory: 44  loss: 1.1142  loss_disc_fake: 0.6232  loss_disc_real: 0.3958  loss_gen: 1.1142
# 08/10 06:48:59 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:48:59 - mmengine - INFO - Epoch(train)  [10][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:54  time: 0.0635  data_time: 0.0475  memory: 44  loss: 1.0066  loss_disc_fake: 0.6778  loss_disc_real: 0.3748  loss_gen: 1.0066
# 08/10 06:48:59 - mmengine - INFO - Saving checkpoint at 10 epochs
# 08/10 06:49:00 - mmengine - INFO - Epoch(train)  [11][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:54  time: 0.0818  data_time: 0.0580  memory: 44  loss: 1.0664  loss_disc_fake: 0.6111  loss_disc_real: 0.3509  loss_gen: 1.0664
# 08/10 06:49:00 - mmengine - INFO - Epoch(train)  [11][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:52  time: 0.0718  data_time: 0.0533  memory: 44  loss: 1.1130  loss_disc_fake: 0.6236  loss_disc_real: 0.3600  loss_gen: 1.1130
# 08/10 06:49:01 - mmengine - INFO - Epoch(train)  [11][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:50  time: 0.0694  data_time: 0.0504  memory: 44  loss: 1.1121  loss_disc_fake: 0.6397  loss_disc_real: 0.3508  loss_gen: 1.1121
# 08/10 06:49:02 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:49:02 - mmengine - INFO - Epoch(train)  [11][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:46  time: 0.0619  data_time: 0.0455  memory: 44  loss: 1.0686  loss_disc_fake: 0.6365  loss_disc_real: 0.4098  loss_gen: 1.0686
# 08/10 06:49:02 - mmengine - INFO - Saving checkpoint at 11 epochs
# 08/10 06:49:03 - mmengine - INFO - Epoch(train)  [12][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:48  time: 0.0939  data_time: 0.0744  memory: 44  loss: 1.1145  loss_disc_fake: 0.6338  loss_disc_real: 0.3800  loss_gen: 1.1145
# 08/10 06:49:03 - mmengine - INFO - Epoch(train)  [12][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:46  time: 0.0673  data_time: 0.0480  memory: 44  loss: 1.1524  loss_disc_fake: 0.6567  loss_disc_real: 0.3998  loss_gen: 1.1524
# 08/10 06:49:04 - mmengine - INFO - Epoch(train)  [12][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:45  time: 0.0773  data_time: 0.0559  memory: 44  loss: 1.0993  loss_disc_fake: 0.6484  loss_disc_real: 0.4188  loss_gen: 1.0993
# 08/10 06:49:05 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:49:05 - mmengine - INFO - Epoch(train)  [12][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:41  time: 0.0609  data_time: 0.0444  memory: 44  loss: 1.1885  loss_disc_fake: 0.6161  loss_disc_real: 0.4361  loss_gen: 1.1885
# 08/10 06:49:05 - mmengine - INFO - Saving checkpoint at 12 epochs
# 08/10 06:49:06 - mmengine - INFO - Epoch(train)  [13][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:41  time: 0.0792  data_time: 0.0586  memory: 44  loss: 1.2131  loss_disc_fake: 0.5812  loss_disc_real: 0.4498  loss_gen: 1.2131
# 08/10 06:49:06 - mmengine - INFO - Epoch(train)  [13][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:39  time: 0.0699  data_time: 0.0506  memory: 44  loss: 1.2734  loss_disc_fake: 0.6309  loss_disc_real: 0.4716  loss_gen: 1.2734
# 08/10 06:49:07 - mmengine - INFO - Epoch(train)  [13][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:37  time: 0.0718  data_time: 0.0511  memory: 44  loss: 1.2698  loss_disc_fake: 0.6151  loss_disc_real: 0.4555  loss_gen: 1.2698
# 08/10 06:49:08 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:49:08 - mmengine - INFO - Epoch(train)  [13][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:34  time: 0.0621  data_time: 0.0459  memory: 44  loss: 1.2727  loss_disc_fake: 0.6544  loss_disc_real: 0.4798  loss_gen: 1.2727
# 08/10 06:49:08 - mmengine - INFO - Saving checkpoint at 13 epochs
# 08/10 06:49:09 - mmengine - INFO - Epoch(train)  [14][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:35  time: 0.0876  data_time: 0.0657  memory: 44  loss: 1.2003  loss_disc_fake: 0.6180  loss_disc_real: 0.4517  loss_gen: 1.2003
# 08/10 06:49:09 - mmengine - INFO - Epoch(train)  [14][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:34  time: 0.0733  data_time: 0.0448  memory: 44  loss: 1.1765  loss_disc_fake: 0.6385  loss_disc_real: 0.4680  loss_gen: 1.1765
# 08/10 06:49:10 - mmengine - INFO - Epoch(train)  [14][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:32  time: 0.0732  data_time: 0.0535  memory: 44  loss: 1.2095  loss_disc_fake: 0.6560  loss_disc_real: 0.4412  loss_gen: 1.2095
# 08/10 06:49:11 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:49:11 - mmengine - INFO - Epoch(train)  [14][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:29  time: 0.0616  data_time: 0.0454  memory: 44  loss: 1.1933  loss_disc_fake: 0.6237  loss_disc_real: 0.4342  loss_gen: 1.1933
# 08/10 06:49:11 - mmengine - INFO - Saving checkpoint at 14 epochs
# 08/10 06:49:12 - mmengine - INFO - Epoch(train)  [15][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:31  time: 0.0895  data_time: 0.0607  memory: 44  loss: 1.2063  loss_disc_fake: 0.6119  loss_disc_real: 0.4212  loss_gen: 1.2063
# 08/10 06:49:12 - mmengine - INFO - Epoch(train)  [15][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:30  time: 0.0749  data_time: 0.0545  memory: 44  loss: 1.1791  loss_disc_fake: 0.6811  loss_disc_real: 0.4240  loss_gen: 1.1791
# 08/10 06:49:13 - mmengine - INFO - Epoch(train)  [15][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:30  time: 0.0829  data_time: 0.0581  memory: 44  loss: 1.0610  loss_disc_fake: 0.7014  loss_disc_real: 0.5037  loss_gen: 1.0610
# 08/10 06:49:14 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:49:14 - mmengine - INFO - Epoch(train)  [15][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:28  time: 0.0723  data_time: 0.0496  memory: 44  loss: 1.1347  loss_disc_fake: 0.6316  loss_disc_real: 0.4570  loss_gen: 1.1347
# 08/10 06:49:14 - mmengine - INFO - Saving checkpoint at 15 epochs
# 08/10 06:49:15 - mmengine - INFO - Epoch(train)  [16][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:29  time: 0.0902  data_time: 0.0650  memory: 44  loss: 1.1233  loss_disc_fake: 0.6779  loss_disc_real: 0.5081  loss_gen: 1.1233
# 08/10 06:49:15 - mmengine - INFO - Epoch(train)  [16][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:27  time: 0.0650  data_time: 0.0446  memory: 44  loss: 1.1578  loss_disc_fake: 0.5804  loss_disc_real: 0.4728  loss_gen: 1.1578
# 08/10 06:49:16 - mmengine - INFO - Epoch(train)  [16][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:25  time: 0.0659  data_time: 0.0479  memory: 44  loss: 1.1888  loss_disc_fake: 0.5791  loss_disc_real: 0.4683  loss_gen: 1.1888
# 08/10 06:49:17 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:49:17 - mmengine - INFO - Epoch(train)  [16][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:23  time: 0.0662  data_time: 0.0489  memory: 44  loss: 1.2073  loss_disc_fake: 0.5392  loss_disc_real: 0.4746  loss_gen: 1.2073
# 08/10 06:49:17 - mmengine - INFO - Saving checkpoint at 16 epochs
# 08/10 06:49:18 - mmengine - INFO - Epoch(train)  [17][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:22  time: 0.0781  data_time: 0.0573  memory: 44  loss: 1.3143  loss_disc_fake: 0.5185  loss_disc_real: 0.4294  loss_gen: 1.3143
# 08/10 06:49:18 - mmengine - INFO - Epoch(train)  [17][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:20  time: 0.0680  data_time: 0.0491  memory: 44  loss: 1.2808  loss_disc_fake: 0.5425  loss_disc_real: 0.4536  loss_gen: 1.2808
# 08/10 06:49:19 - mmengine - INFO - Epoch(train)  [17][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:19  time: 0.0736  data_time: 0.0549  memory: 44  loss: 1.2429  loss_disc_fake: 0.5138  loss_disc_real: 0.4839  loss_gen: 1.2429
# 08/10 06:49:20 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:49:20 - mmengine - INFO - Epoch(train)  [17][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:17  time: 0.0655  data_time: 0.0484  memory: 44  loss: 1.2470  loss_disc_fake: 0.5620  loss_disc_real: 0.4788  loss_gen: 1.2470
# 08/10 06:49:20 - mmengine - INFO - Saving checkpoint at 17 epochs
# 08/10 06:49:20 - mmengine - INFO - Epoch(train)  [18][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:16  time: 0.0754  data_time: 0.0556  memory: 44  loss: 1.1572  loss_disc_fake: 0.6293  loss_disc_real: 0.4979  loss_gen: 1.1572
# 08/10 06:49:21 - mmengine - INFO - Epoch(train)  [18][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:15  time: 0.0684  data_time: 0.0509  memory: 44  loss: 1.1614  loss_disc_fake: 0.6106  loss_disc_real: 0.5219  loss_gen: 1.1614
# 08/10 06:49:22 - mmengine - INFO - Epoch(train)  [18][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:13  time: 0.0693  data_time: 0.0513  memory: 44  loss: 1.1967  loss_disc_fake: 0.5680  loss_disc_real: 0.4633  loss_gen: 1.1967
# 08/10 06:49:22 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:49:22 - mmengine - INFO - Epoch(train)  [18][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:11  time: 0.0611  data_time: 0.0448  memory: 44  loss: 1.1494  loss_disc_fake: 0.5699  loss_disc_real: 0.4635  loss_gen: 1.1494
# 08/10 06:49:22 - mmengine - INFO - Saving checkpoint at 18 epochs
# 08/10 06:49:23 - mmengine - INFO - Epoch(train)  [19][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:11  time: 0.0850  data_time: 0.0649  memory: 44  loss: 1.1685  loss_disc_fake: 0.5473  loss_disc_real: 0.4501  loss_gen: 1.1685
# 08/10 06:49:24 - mmengine - INFO - Epoch(train)  [19][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:09  time: 0.0650  data_time: 0.0464  memory: 44  loss: 1.2122  loss_disc_fake: 0.6055  loss_disc_real: 0.4979  loss_gen: 1.2122
# 08/10 06:49:25 - mmengine - INFO - Epoch(train)  [19][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:08  time: 0.0755  data_time: 0.0522  memory: 44  loss: 1.1309  loss_disc_fake: 0.6064  loss_disc_real: 0.4801  loss_gen: 1.1309
# 08/10 06:49:25 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:49:25 - mmengine - INFO - Epoch(train)  [19][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:06  time: 0.0602  data_time: 0.0439  memory: 44  loss: 1.1374  loss_disc_fake: 0.6233  loss_disc_real: 0.5312  loss_gen: 1.1374
# 08/10 06:49:25 - mmengine - INFO - Saving checkpoint at 19 epochs
# 08/10 06:49:26 - mmengine - INFO - Epoch(train)  [20][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:06  time: 0.0837  data_time: 0.0639  memory: 44  loss: 1.2164  loss_disc_fake: 0.5188  loss_disc_real: 0.4473  loss_gen: 1.2164
# 08/10 06:49:27 - mmengine - INFO - Epoch(train)  [20][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:04  time: 0.0659  data_time: 0.0465  memory: 44  loss: 1.2605  loss_disc_fake: 0.5633  loss_disc_real: 0.4856  loss_gen: 1.2605
# 08/10 06:49:27 - mmengine - INFO - Epoch(train)  [20][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:03  time: 0.0669  data_time: 0.0488  memory: 44  loss: 1.2338  loss_disc_fake: 0.5841  loss_disc_real: 0.4961  loss_gen: 1.2338
# 08/10 06:49:28 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:49:28 - mmengine - INFO - Epoch(train)  [20][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:00  time: 0.0602  data_time: 0.0439  memory: 44  loss: 1.1777  loss_disc_fake: 0.5650  loss_disc_real: 0.5206  loss_gen: 1.1777
# 08/10 06:49:28 - mmengine - INFO - Saving checkpoint at 20 epochs
# 08/10 06:49:29 - mmengine - INFO - Epoch(train)  [21][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:10:01  time: 0.0885  data_time: 0.0697  memory: 44  loss: 1.2746  loss_disc_fake: 0.5523  loss_disc_real: 0.4534  loss_gen: 1.2746
# 08/10 06:49:30 - mmengine - INFO - Epoch(train)  [21][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:59  time: 0.0664  data_time: 0.0454  memory: 44  loss: 1.1998  loss_disc_fake: 0.5802  loss_disc_real: 0.5120  loss_gen: 1.1998
# 08/10 06:49:30 - mmengine - INFO - Epoch(train)  [21][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:58  time: 0.0693  data_time: 0.0503  memory: 44  loss: 1.2008  loss_disc_fake: 0.5901  loss_disc_real: 0.5055  loss_gen: 1.2008
# 08/10 06:49:31 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:49:31 - mmengine - INFO - Epoch(train)  [21][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:56  time: 0.0602  data_time: 0.0436  memory: 44  loss: 1.2294  loss_disc_fake: 0.5834  loss_disc_real: 0.4629  loss_gen: 1.2294
# 08/10 06:49:31 - mmengine - INFO - Saving checkpoint at 21 epochs
# 08/10 06:49:32 - mmengine - INFO - Epoch(train)  [22][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:57  time: 0.0908  data_time: 0.0700  memory: 44  loss: 1.1800  loss_disc_fake: 0.5816  loss_disc_real: 0.4992  loss_gen: 1.1800
# 08/10 06:49:33 - mmengine - INFO - Epoch(train)  [22][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:55  time: 0.0614  data_time: 0.0404  memory: 44  loss: 1.1338  loss_disc_fake: 0.5791  loss_disc_real: 0.5031  loss_gen: 1.1338
# 08/10 06:49:33 - mmengine - INFO - Epoch(train)  [22][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:53  time: 0.0669  data_time: 0.0491  memory: 44  loss: 1.1968  loss_disc_fake: 0.5859  loss_disc_real: 0.4993  loss_gen: 1.1968
# 08/10 06:49:34 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:49:34 - mmengine - INFO - Epoch(train)  [22][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:52  time: 0.0660  data_time: 0.0438  memory: 44  loss: 1.1574  loss_disc_fake: 0.5719  loss_disc_real: 0.5059  loss_gen: 1.1574
# 08/10 06:49:34 - mmengine - INFO - Saving checkpoint at 22 epochs
# 08/10 06:49:35 - mmengine - INFO - Epoch(train)  [23][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:51  time: 0.0770  data_time: 0.0572  memory: 44  loss: 1.2883  loss_disc_fake: 0.5509  loss_disc_real: 0.4529  loss_gen: 1.2883
# 08/10 06:49:35 - mmengine - INFO - Epoch(train)  [23][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:50  time: 0.0687  data_time: 0.0501  memory: 44  loss: 1.2521  loss_disc_fake: 0.5918  loss_disc_real: 0.4901  loss_gen: 1.2521
# 08/10 06:49:36 - mmengine - INFO - Epoch(train)  [23][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:49  time: 0.0727  data_time: 0.0528  memory: 44  loss: 1.1352  loss_disc_fake: 0.5653  loss_disc_real: 0.5251  loss_gen: 1.1352
# 08/10 06:49:37 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:49:37 - mmengine - INFO - Epoch(train)  [23][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:47  time: 0.0589  data_time: 0.0425  memory: 44  loss: 1.1964  loss_disc_fake: 0.5731  loss_disc_real: 0.5147  loss_gen: 1.1964
# 08/10 06:49:37 - mmengine - INFO - Saving checkpoint at 23 epochs
# 08/10 06:49:38 - mmengine - INFO - Epoch(train)  [24][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:47  time: 0.0848  data_time: 0.0626  memory: 44  loss: 1.2815  loss_disc_fake: 0.5238  loss_disc_real: 0.4863  loss_gen: 1.2815
# 08/10 06:49:38 - mmengine - INFO - Epoch(train)  [24][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:46  time: 0.0693  data_time: 0.0512  memory: 44  loss: 1.2756  loss_disc_fake: 0.5177  loss_disc_real: 0.4638  loss_gen: 1.2756
# 08/10 06:49:39 - mmengine - INFO - Epoch(train)  [24][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:44  time: 0.0688  data_time: 0.0508  memory: 44  loss: 1.3196  loss_disc_fake: 0.6152  loss_disc_real: 0.5564  loss_gen: 1.3196
# 08/10 06:49:40 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:49:40 - mmengine - INFO - Epoch(train)  [24][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:42  time: 0.0587  data_time: 0.0426  memory: 44  loss: 1.1839  loss_disc_fake: 0.5802  loss_disc_real: 0.5132  loss_gen: 1.1839
# 08/10 06:49:40 - mmengine - INFO - Saving checkpoint at 24 epochs
# 08/10 06:49:40 - mmengine - INFO - Epoch(train)  [25][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:42  time: 0.0814  data_time: 0.0605  memory: 44  loss: 1.2428  loss_disc_fake: 0.6371  loss_disc_real: 0.5392  loss_gen: 1.2428
# 08/10 06:49:41 - mmengine - INFO - Epoch(train)  [25][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:41  time: 0.0667  data_time: 0.0484  memory: 44  loss: 1.2340  loss_disc_fake: 0.5453  loss_disc_real: 0.5199  loss_gen: 1.2340
# 08/10 06:49:42 - mmengine - INFO - Epoch(train)  [25][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:40  time: 0.0708  data_time: 0.0522  memory: 44  loss: 1.2139  loss_disc_fake: 0.5764  loss_disc_real: 0.5478  loss_gen: 1.2139
# 08/10 06:49:42 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:49:42 - mmengine - INFO - Epoch(train)  [25][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:38  time: 0.0592  data_time: 0.0429  memory: 44  loss: 1.2107  loss_disc_fake: 0.6498  loss_disc_real: 0.4791  loss_gen: 1.2107
# 08/10 06:49:42 - mmengine - INFO - Saving checkpoint at 25 epochs
# 08/10 06:49:43 - mmengine - INFO - Epoch(train)  [26][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:38  time: 0.0828  data_time: 0.0647  memory: 44  loss: 1.1733  loss_disc_fake: 0.6252  loss_disc_real: 0.5261  loss_gen: 1.1733
# 08/10 06:49:44 - mmengine - INFO - Epoch(train)  [26][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:37  time: 0.0729  data_time: 0.0467  memory: 44  loss: 1.2181  loss_disc_fake: 0.5371  loss_disc_real: 0.4547  loss_gen: 1.2181
# 08/10 06:49:45 - mmengine - INFO - Epoch(train)  [26][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:36  time: 0.0697  data_time: 0.0512  memory: 44  loss: 1.2313  loss_disc_fake: 0.5175  loss_disc_real: 0.4372  loss_gen: 1.2313
# 08/10 06:49:45 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:49:45 - mmengine - INFO - Epoch(train)  [26][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:34  time: 0.0585  data_time: 0.0423  memory: 44  loss: 1.2778  loss_disc_fake: 0.5431  loss_disc_real: 0.4473  loss_gen: 1.2778
# 08/10 06:49:45 - mmengine - INFO - Saving checkpoint at 26 epochs
# 08/10 06:49:46 - mmengine - INFO - Epoch(train)  [27][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:33  time: 0.0766  data_time: 0.0580  memory: 44  loss: 1.3138  loss_disc_fake: 0.5641  loss_disc_real: 0.4995  loss_gen: 1.3138
# 08/10 06:49:47 - mmengine - INFO - Epoch(train)  [27][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:33  time: 0.0717  data_time: 0.0519  memory: 44  loss: 1.2240  loss_disc_fake: 0.4993  loss_disc_real: 0.4782  loss_gen: 1.2240
# 08/10 06:49:47 - mmengine - INFO - Epoch(train)  [27][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:32  time: 0.0704  data_time: 0.0507  memory: 44  loss: 1.3211  loss_disc_fake: 0.5841  loss_disc_real: 0.5413  loss_gen: 1.3211
# 08/10 06:49:48 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:49:48 - mmengine - INFO - Epoch(train)  [27][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:30  time: 0.0594  data_time: 0.0430  memory: 44  loss: 1.2215  loss_disc_fake: 0.5137  loss_disc_real: 0.4972  loss_gen: 1.2215
# 08/10 06:49:48 - mmengine - INFO - Saving checkpoint at 27 epochs
# 08/10 06:49:49 - mmengine - INFO - Epoch(train)  [28][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:31  time: 0.0956  data_time: 0.0773  memory: 44  loss: 1.4168  loss_disc_fake: 0.5393  loss_disc_real: 0.4710  loss_gen: 1.4168
# 08/10 06:49:50 - mmengine - INFO - Epoch(train)  [28][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:29  time: 0.0584  data_time: 0.0403  memory: 44  loss: 1.3313  loss_disc_fake: 0.5616  loss_disc_real: 0.5396  loss_gen: 1.3313
# 08/10 06:49:50 - mmengine - INFO - Epoch(train)  [28][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:28  time: 0.0711  data_time: 0.0523  memory: 44  loss: 1.2074  loss_disc_fake: 0.5261  loss_disc_real: 0.5065  loss_gen: 1.2074
# 08/10 06:49:51 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:49:51 - mmengine - INFO - Epoch(train)  [28][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:26  time: 0.0613  data_time: 0.0452  memory: 44  loss: 1.2957  loss_disc_fake: 0.5844  loss_disc_real: 0.5267  loss_gen: 1.2957
# 08/10 06:49:51 - mmengine - INFO - Saving checkpoint at 28 epochs
# 08/10 06:49:52 - mmengine - INFO - Epoch(train)  [29][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:26  time: 0.0802  data_time: 0.0584  memory: 44  loss: 1.2246  loss_disc_fake: 0.5326  loss_disc_real: 0.4887  loss_gen: 1.2246
# 08/10 06:49:52 - mmengine - INFO - Epoch(train)  [29][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:25  time: 0.0681  data_time: 0.0491  memory: 44  loss: 1.2596  loss_disc_fake: 0.5471  loss_disc_real: 0.5093  loss_gen: 1.2596
# 08/10 06:49:53 - mmengine - INFO - Epoch(train)  [29][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:24  time: 0.0752  data_time: 0.0557  memory: 44  loss: 1.3799  loss_disc_fake: 0.5013  loss_disc_real: 0.4100  loss_gen: 1.3799
# 08/10 06:49:54 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:49:54 - mmengine - INFO - Epoch(train)  [29][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:23  time: 0.0626  data_time: 0.0464  memory: 44  loss: 1.4318  loss_disc_fake: 0.5190  loss_disc_real: 0.4463  loss_gen: 1.4318
# 08/10 06:49:54 - mmengine - INFO - Saving checkpoint at 29 epochs
# 08/10 06:49:55 - mmengine - INFO - Epoch(train)  [30][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:23  time: 0.0829  data_time: 0.0642  memory: 44  loss: 1.4009  loss_disc_fake: 0.5432  loss_disc_real: 0.4918  loss_gen: 1.4009
# 08/10 06:49:55 - mmengine - INFO - Epoch(train)  [30][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:21  time: 0.0694  data_time: 0.0507  memory: 44  loss: 1.3360  loss_disc_fake: 0.5959  loss_disc_real: 0.5404  loss_gen: 1.3360
# 08/10 06:49:56 - mmengine - INFO - Epoch(train)  [30][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:21  time: 0.0699  data_time: 0.0511  memory: 44  loss: 1.2666  loss_disc_fake: 0.5044  loss_disc_real: 0.5067  loss_gen: 1.2666
# 08/10 06:49:57 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:49:57 - mmengine - INFO - Epoch(train)  [30][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:19  time: 0.0609  data_time: 0.0450  memory: 44  loss: 1.4025  loss_disc_fake: 0.5346  loss_disc_real: 0.4994  loss_gen: 1.4025
# 08/10 06:49:57 - mmengine - INFO - Saving checkpoint at 30 epochs
# 08/10 06:49:58 - mmengine - INFO - Epoch(train)  [31][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:19  time: 0.0797  data_time: 0.0605  memory: 44  loss: 1.4403  loss_disc_fake: 0.4869  loss_disc_real: 0.4592  loss_gen: 1.4403
# 08/10 06:49:58 - mmengine - INFO - Epoch(train)  [31][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:18  time: 0.0679  data_time: 0.0498  memory: 44  loss: 1.3990  loss_disc_fake: 0.4839  loss_disc_real: 0.4683  loss_gen: 1.3990
# 08/10 06:49:59 - mmengine - INFO - Epoch(train)  [31][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:17  time: 0.0726  data_time: 0.0549  memory: 44  loss: 1.4876  loss_disc_fake: 0.4781  loss_disc_real: 0.4527  loss_gen: 1.4876
# 08/10 06:50:00 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:50:00 - mmengine - INFO - Epoch(train)  [31][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:15  time: 0.0619  data_time: 0.0458  memory: 44  loss: 1.4519  loss_disc_fake: 0.4864  loss_disc_real: 0.4609  loss_gen: 1.4519
# 08/10 06:50:00 - mmengine - INFO - Saving checkpoint at 31 epochs
# 08/10 06:50:00 - mmengine - INFO - Epoch(train)  [32][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:15  time: 0.0805  data_time: 0.0620  memory: 44  loss: 1.3924  loss_disc_fake: 0.4914  loss_disc_real: 0.4530  loss_gen: 1.3924
# 08/10 06:50:01 - mmengine - INFO - Epoch(train)  [32][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:14  time: 0.0650  data_time: 0.0448  memory: 44  loss: 1.4545  loss_disc_fake: 0.5523  loss_disc_real: 0.5025  loss_gen: 1.4545
# 08/10 06:50:02 - mmengine - INFO - Epoch(train)  [32][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:13  time: 0.0731  data_time: 0.0540  memory: 44  loss: 1.4125  loss_disc_fake: 0.4673  loss_disc_real: 0.4495  loss_gen: 1.4125
# 08/10 06:50:02 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:50:02 - mmengine - INFO - Epoch(train)  [32][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:12  time: 0.0668  data_time: 0.0500  memory: 44  loss: 1.4207  loss_disc_fake: 0.5339  loss_disc_real: 0.4877  loss_gen: 1.4207
# 08/10 06:50:02 - mmengine - INFO - Saving checkpoint at 32 epochs
# 08/10 06:50:03 - mmengine - INFO - Epoch(train)  [33][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:11  time: 0.0793  data_time: 0.0602  memory: 44  loss: 1.2650  loss_disc_fake: 0.5227  loss_disc_real: 0.5307  loss_gen: 1.2650
# 08/10 06:50:04 - mmengine - INFO - Epoch(train)  [33][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:11  time: 0.0761  data_time: 0.0524  memory: 44  loss: 1.3593  loss_disc_fake: 0.4782  loss_disc_real: 0.4466  loss_gen: 1.3593
# 08/10 06:50:05 - mmengine - INFO - Epoch(train)  [33][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:10  time: 0.0684  data_time: 0.0494  memory: 44  loss: 1.4471  loss_disc_fake: 0.5210  loss_disc_real: 0.4498  loss_gen: 1.4471
# 08/10 06:50:05 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:50:05 - mmengine - INFO - Epoch(train)  [33][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:08  time: 0.0595  data_time: 0.0430  memory: 44  loss: 1.3475  loss_disc_fake: 0.4988  loss_disc_real: 0.5069  loss_gen: 1.3475
# 08/10 06:50:05 - mmengine - INFO - Saving checkpoint at 33 epochs
# 08/10 06:50:06 - mmengine - INFO - Epoch(train)  [34][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:08  time: 0.0788  data_time: 0.0587  memory: 44  loss: 1.3705  loss_disc_fake: 0.4745  loss_disc_real: 0.4287  loss_gen: 1.3705
# 08/10 06:50:07 - mmengine - INFO - Epoch(train)  [34][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:07  time: 0.0667  data_time: 0.0488  memory: 44  loss: 1.4760  loss_disc_fake: 0.4827  loss_disc_real: 0.4565  loss_gen: 1.4760
# 08/10 06:50:07 - mmengine - INFO - Epoch(train)  [34][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:06  time: 0.0682  data_time: 0.0495  memory: 44  loss: 1.4253  loss_disc_fake: 0.4727  loss_disc_real: 0.4208  loss_gen: 1.4253
# 08/10 06:50:08 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:50:08 - mmengine - INFO - Epoch(train)  [34][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:04  time: 0.0588  data_time: 0.0423  memory: 44  loss: 1.3924  loss_disc_fake: 0.4536  loss_disc_real: 0.4243  loss_gen: 1.3924
# 08/10 06:50:08 - mmengine - INFO - Saving checkpoint at 34 epochs
# 08/10 06:50:09 - mmengine - INFO - Epoch(train)  [35][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:04  time: 0.0877  data_time: 0.0663  memory: 44  loss: 1.3912  loss_disc_fake: 0.4846  loss_disc_real: 0.4673  loss_gen: 1.3912
# 08/10 06:50:10 - mmengine - INFO - Epoch(train)  [35][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:03  time: 0.0695  data_time: 0.0512  memory: 44  loss: 1.3649  loss_disc_fake: 0.5169  loss_disc_real: 0.4615  loss_gen: 1.3649
# 08/10 06:50:10 - mmengine - INFO - Epoch(train)  [35][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:02  time: 0.0712  data_time: 0.0522  memory: 44  loss: 1.3117  loss_disc_fake: 0.4841  loss_disc_real: 0.4467  loss_gen: 1.3117
# 08/10 06:50:11 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:50:11 - mmengine - INFO - Epoch(train)  [35][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:01  time: 0.0595  data_time: 0.0432  memory: 44  loss: 1.5016  loss_disc_fake: 0.5430  loss_disc_real: 0.4968  loss_gen: 1.5016
# 08/10 06:50:11 - mmengine - INFO - Saving checkpoint at 35 epochs
# 08/10 06:50:12 - mmengine - INFO - Epoch(train)  [36][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:01  time: 0.0890  data_time: 0.0682  memory: 44  loss: 1.4073  loss_disc_fake: 0.5821  loss_disc_real: 0.4805  loss_gen: 1.4073
# 08/10 06:50:12 - mmengine - INFO - Epoch(train)  [36][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:09:00  time: 0.0616  data_time: 0.0417  memory: 44  loss: 1.2734  loss_disc_fake: 0.6280  loss_disc_real: 0.5538  loss_gen: 1.2734
# 08/10 06:50:13 - mmengine - INFO - Epoch(train)  [36][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:08:59  time: 0.0747  data_time: 0.0520  memory: 44  loss: 1.2051  loss_disc_fake: 0.5805  loss_disc_real: 0.5512  loss_gen: 1.2051
# 08/10 06:50:14 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:50:14 - mmengine - INFO - Epoch(train)  [36][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:08:58  time: 0.0646  data_time: 0.0484  memory: 44  loss: 1.2669  loss_disc_fake: 0.5309  loss_disc_real: 0.4710  loss_gen: 1.2669
# 08/10 06:50:14 - mmengine - INFO - Saving checkpoint at 36 epochs
# 08/10 06:50:15 - mmengine - INFO - Epoch(train)  [37][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:08:58  time: 0.0812  data_time: 0.0589  memory: 44  loss: 1.3687  loss_disc_fake: 0.5342  loss_disc_real: 0.4971  loss_gen: 1.3687
# 08/10 06:50:15 - mmengine - INFO - Epoch(train)  [37][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:08:57  time: 0.0719  data_time: 0.0509  memory: 44  loss: 1.2880  loss_disc_fake: 0.4782  loss_disc_real: 0.4930  loss_gen: 1.2880
# 08/10 06:50:16 - mmengine - INFO - Epoch(train)  [37][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:08:56  time: 0.0715  data_time: 0.0514  memory: 44  loss: 1.4354  loss_disc_fake: 0.5584  loss_disc_real: 0.4708  loss_gen: 1.4354
# 08/10 06:50:17 - mmengine - INFO - Exp name: 20230810_064827
# ...
# 08/10 06:58:37 - mmengine - INFO - Epoch(train) [208][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:35  time: 0.0708  data_time: 0.0522  memory: 44  loss: 1.5245  loss_disc_fake: 0.4030  loss_disc_real: 0.4479  loss_gen: 1.5245
# 08/10 06:58:37 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:58:37 - mmengine - INFO - Epoch(train) [208][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:34  time: 0.0686  data_time: 0.0492  memory: 44  loss: 1.5327  loss_disc_fake: 0.3763  loss_disc_real: 0.4408  loss_gen: 1.5327
# 08/10 06:58:37 - mmengine - INFO - Saving checkpoint at 208 epochs
# 08/10 06:58:38 - mmengine - INFO - Epoch(train) [209][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:34  time: 0.1054  data_time: 0.0805  memory: 44  loss: 1.5030  loss_disc_fake: 0.4074  loss_disc_real: 0.4831  loss_gen: 1.5030
# 08/10 06:58:39 - mmengine - INFO - Epoch(train) [209][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:33  time: 0.0951  data_time: 0.0660  memory: 44  loss: 1.5885  loss_disc_fake: 0.4620  loss_disc_real: 0.5093  loss_gen: 1.5885
# 08/10 06:58:40 - mmengine - INFO - Epoch(train) [209][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:32  time: 0.0874  data_time: 0.0623  memory: 44  loss: 1.5129  loss_disc_fake: 0.4367  loss_disc_real: 0.4825  loss_gen: 1.5129
# 08/10 06:58:41 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:58:41 - mmengine - INFO - Epoch(train) [209][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:31  time: 0.0767  data_time: 0.0543  memory: 44  loss: 1.6371  loss_disc_fake: 0.4522  loss_disc_real: 0.4340  loss_gen: 1.6371
# 08/10 06:58:41 - mmengine - INFO - Saving checkpoint at 209 epochs
# 08/10 06:58:42 - mmengine - INFO - Epoch(train) [210][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:31  time: 0.0913  data_time: 0.0677  memory: 44  loss: 1.5986  loss_disc_fake: 0.4196  loss_disc_real: 0.4323  loss_gen: 1.5986
# 08/10 06:58:43 - mmengine - INFO - Epoch(train) [210][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:30  time: 0.0730  data_time: 0.0536  memory: 44  loss: 1.5625  loss_disc_fake: 0.4431  loss_disc_real: 0.4925  loss_gen: 1.5625
# 08/10 06:58:44 - mmengine - INFO - Epoch(train) [210][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:29  time: 0.0800  data_time: 0.0568  memory: 44  loss: 1.4211  loss_disc_fake: 0.3770  loss_disc_real: 0.4492  loss_gen: 1.4211
# 08/10 06:58:44 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:58:44 - mmengine - INFO - Epoch(train) [210][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:28  time: 0.0623  data_time: 0.0460  memory: 44  loss: 1.6970  loss_disc_fake: 0.4951  loss_disc_real: 0.5055  loss_gen: 1.6970
# 08/10 06:58:44 - mmengine - INFO - Saving checkpoint at 210 epochs
# 08/10 06:58:45 - mmengine - INFO - Epoch(train) [211][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:28  time: 0.0843  data_time: 0.0652  memory: 44  loss: 1.4700  loss_disc_fake: 0.4402  loss_disc_real: 0.4883  loss_gen: 1.4700
# 08/10 06:58:46 - mmengine - INFO - Epoch(train) [211][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:27  time: 0.0705  data_time: 0.0520  memory: 44  loss: 1.5481  loss_disc_fake: 0.5415  loss_disc_real: 0.5028  loss_gen: 1.5481
# 08/10 06:58:46 - mmengine - INFO - Epoch(train) [211][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:26  time: 0.0693  data_time: 0.0481  memory: 44  loss: 1.4643  loss_disc_fake: 0.5335  loss_disc_real: 0.6440  loss_gen: 1.4643
# 08/10 06:58:47 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:58:47 - mmengine - INFO - Epoch(train) [211][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:26  time: 0.0616  data_time: 0.0441  memory: 44  loss: 1.3887  loss_disc_fake: 0.4961  loss_disc_real: 0.5397  loss_gen: 1.3887
# 08/10 06:58:47 - mmengine - INFO - Saving checkpoint at 211 epochs
# 08/10 06:58:48 - mmengine - INFO - Epoch(train) [212][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:25  time: 0.0834  data_time: 0.0623  memory: 44  loss: 1.5392  loss_disc_fake: 0.4865  loss_disc_real: 0.4970  loss_gen: 1.5392
# 08/10 06:58:49 - mmengine - INFO - Epoch(train) [212][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:24  time: 0.0673  data_time: 0.0451  memory: 44  loss: 1.5138  loss_disc_fake: 0.4447  loss_disc_real: 0.5177  loss_gen: 1.5138
# 08/10 06:58:49 - mmengine - INFO - Epoch(train) [212][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:23  time: 0.0702  data_time: 0.0515  memory: 44  loss: 1.5495  loss_disc_fake: 0.5671  loss_disc_real: 0.5948  loss_gen: 1.5495
# 08/10 06:58:50 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:58:50 - mmengine - INFO - Epoch(train) [212][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:23  time: 0.0646  data_time: 0.0482  memory: 44  loss: 1.4171  loss_disc_fake: 0.5238  loss_disc_real: 0.5831  loss_gen: 1.4171
# 08/10 06:58:50 - mmengine - INFO - Saving checkpoint at 212 epochs
# 08/10 06:58:51 - mmengine - INFO - Epoch(train) [213][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:22  time: 0.0948  data_time: 0.0716  memory: 44  loss: 1.4425  loss_disc_fake: 0.4460  loss_disc_real: 0.5001  loss_gen: 1.4425
# 08/10 06:58:52 - mmengine - INFO - Epoch(train) [213][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:21  time: 0.0606  data_time: 0.0414  memory: 44  loss: 1.4337  loss_disc_fake: 0.4135  loss_disc_real: 0.4786  loss_gen: 1.4337
# 08/10 06:58:52 - mmengine - INFO - Epoch(train) [213][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:21  time: 0.0703  data_time: 0.0527  memory: 44  loss: 1.4220  loss_disc_fake: 0.3972  loss_disc_real: 0.4752  loss_gen: 1.4220
# 08/10 06:58:53 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:58:53 - mmengine - INFO - Epoch(train) [213][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:20  time: 0.0596  data_time: 0.0432  memory: 44  loss: 1.5038  loss_disc_fake: 0.4636  loss_disc_real: 0.5261  loss_gen: 1.5038
# 08/10 06:58:53 - mmengine - INFO - Saving checkpoint at 213 epochs
# 08/10 06:58:54 - mmengine - INFO - Epoch(train) [214][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:19  time: 0.0808  data_time: 0.0576  memory: 44  loss: 1.3767  loss_disc_fake: 0.4838  loss_disc_real: 0.5190  loss_gen: 1.3767
# 08/10 06:58:54 - mmengine - INFO - Epoch(train) [214][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:18  time: 0.0705  data_time: 0.0511  memory: 44  loss: 1.4690  loss_disc_fake: 0.5193  loss_disc_real: 0.5850  loss_gen: 1.4690
# 08/10 06:58:55 - mmengine - INFO - Epoch(train) [214][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:18  time: 0.0726  data_time: 0.0486  memory: 44  loss: 1.3789  loss_disc_fake: 0.4037  loss_disc_real: 0.4971  loss_gen: 1.3789
# 08/10 06:58:56 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:58:56 - mmengine - INFO - Epoch(train) [214][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:17  time: 0.0613  data_time: 0.0448  memory: 44  loss: 1.5040  loss_disc_fake: 0.4783  loss_disc_real: 0.5190  loss_gen: 1.5040
# 08/10 06:58:56 - mmengine - INFO - Saving checkpoint at 214 epochs
# 08/10 06:58:57 - mmengine - INFO - Epoch(train) [215][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:16  time: 0.0818  data_time: 0.0611  memory: 44  loss: 1.4708  loss_disc_fake: 0.4642  loss_disc_real: 0.4957  loss_gen: 1.4708
# 08/10 06:58:57 - mmengine - INFO - Epoch(train) [215][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:15  time: 0.0621  data_time: 0.0439  memory: 44  loss: 1.5490  loss_disc_fake: 0.4643  loss_disc_real: 0.5164  loss_gen: 1.5490
# 08/10 06:58:58 - mmengine - INFO - Epoch(train) [215][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:15  time: 0.0692  data_time: 0.0491  memory: 44  loss: 1.5477  loss_disc_fake: 0.4303  loss_disc_real: 0.4872  loss_gen: 1.5477
# 08/10 06:58:59 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:58:59 - mmengine - INFO - Epoch(train) [215][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:14  time: 0.0668  data_time: 0.0507  memory: 44  loss: 1.4939  loss_disc_fake: 0.3934  loss_disc_real: 0.4622  loss_gen: 1.4939
# 08/10 06:58:59 - mmengine - INFO - Saving checkpoint at 215 epochs
# 08/10 06:59:00 - mmengine - INFO - Epoch(train) [216][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:13  time: 0.0929  data_time: 0.0659  memory: 44  loss: 1.4287  loss_disc_fake: 0.3864  loss_disc_real: 0.4404  loss_gen: 1.4287
# 08/10 06:59:00 - mmengine - INFO - Epoch(train) [216][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:13  time: 0.0652  data_time: 0.0466  memory: 44  loss: 1.4038  loss_disc_fake: 0.4120  loss_disc_real: 0.4649  loss_gen: 1.4038
# 08/10 06:59:01 - mmengine - INFO - Epoch(train) [216][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:12  time: 0.0701  data_time: 0.0513  memory: 44  loss: 1.5227  loss_disc_fake: 0.4593  loss_disc_real: 0.5382  loss_gen: 1.5227
# 08/10 06:59:02 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:59:02 - mmengine - INFO - Epoch(train) [216][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:11  time: 0.0894  data_time: 0.0604  memory: 44  loss: 1.5110  loss_disc_fake: 0.3718  loss_disc_real: 0.4342  loss_gen: 1.5110
# 08/10 06:59:02 - mmengine - INFO - Saving checkpoint at 216 epochs
# 08/10 06:59:03 - mmengine - INFO - Epoch(train) [217][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:10  time: 0.1082  data_time: 0.0839  memory: 44  loss: 1.4929  loss_disc_fake: 0.4200  loss_disc_real: 0.4736  loss_gen: 1.4929
# 08/10 06:59:04 - mmengine - INFO - Epoch(train) [217][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:10  time: 0.1042  data_time: 0.0683  memory: 44  loss: 1.4621  loss_disc_fake: 0.4159  loss_disc_real: 0.4848  loss_gen: 1.4621
# 08/10 06:59:05 - mmengine - INFO - Epoch(train) [217][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:09  time: 0.0880  data_time: 0.0567  memory: 44  loss: 1.5543  loss_disc_fake: 0.4608  loss_disc_real: 0.5592  loss_gen: 1.5543
# 08/10 06:59:06 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:59:06 - mmengine - INFO - Epoch(train) [217][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:08  time: 0.0791  data_time: 0.0566  memory: 44  loss: 1.5214  loss_disc_fake: 0.4181  loss_disc_real: 0.4765  loss_gen: 1.5214
# 08/10 06:59:06 - mmengine - INFO - Saving checkpoint at 217 epochs
# 08/10 06:59:07 - mmengine - INFO - Epoch(train) [218][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:07  time: 0.0812  data_time: 0.0591  memory: 44  loss: 1.5470  loss_disc_fake: 0.4960  loss_disc_real: 0.5814  loss_gen: 1.5470
# 08/10 06:59:07 - mmengine - INFO - Epoch(train) [218][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:07  time: 0.0669  data_time: 0.0480  memory: 44  loss: 1.5572  loss_disc_fake: 0.4933  loss_disc_real: 0.5968  loss_gen: 1.5572
# 08/10 06:59:08 - mmengine - INFO - Epoch(train) [218][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:06  time: 0.0674  data_time: 0.0492  memory: 44  loss: 1.5797  loss_disc_fake: 0.4825  loss_disc_real: 0.5118  loss_gen: 1.5797
# 08/10 06:59:09 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:59:09 - mmengine - INFO - Epoch(train) [218][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:05  time: 0.0599  data_time: 0.0433  memory: 44  loss: 1.5395  loss_disc_fake: 0.4283  loss_disc_real: 0.4366  loss_gen: 1.5395
# 08/10 06:59:09 - mmengine - INFO - Saving checkpoint at 218 epochs
# 08/10 06:59:09 - mmengine - INFO - Epoch(train) [219][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:05  time: 0.0799  data_time: 0.0572  memory: 44  loss: 1.6044  loss_disc_fake: 0.4313  loss_disc_real: 0.4546  loss_gen: 1.6044
# 08/10 06:59:10 - mmengine - INFO - Epoch(train) [219][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:04  time: 0.0715  data_time: 0.0503  memory: 44  loss: 1.5511  loss_disc_fake: 0.3795  loss_disc_real: 0.4454  loss_gen: 1.5511
# 08/10 06:59:11 - mmengine - INFO - Epoch(train) [219][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:03  time: 0.0733  data_time: 0.0484  memory: 44  loss: 1.6251  loss_disc_fake: 0.4023  loss_disc_real: 0.4429  loss_gen: 1.6251
# 08/10 06:59:11 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:59:11 - mmengine - INFO - Epoch(train) [219][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:02  time: 0.0595  data_time: 0.0433  memory: 44  loss: 1.6322  loss_disc_fake: 0.4131  loss_disc_real: 0.4031  loss_gen: 1.6322
# 08/10 06:59:11 - mmengine - INFO - Saving checkpoint at 219 epochs
# 08/10 06:59:12 - mmengine - INFO - Epoch(train) [220][10/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:02  time: 0.0856  data_time: 0.0654  memory: 44  loss: 1.6436  loss_disc_fake: 0.4885  loss_disc_real: 0.4865  loss_gen: 1.6436
# 08/10 06:59:13 - mmengine - INFO - Epoch(train) [220][20/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:01  time: 0.0650  data_time: 0.0462  memory: 44  loss: 1.5438  loss_disc_fake: 0.4278  loss_disc_real: 0.5184  loss_gen: 1.5438
# 08/10 06:59:14 - mmengine - INFO - Epoch(train) [220][30/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:00  time: 0.0695  data_time: 0.0521  memory: 44  loss: 1.4640  loss_disc_fake: 0.4114  loss_disc_real: 0.5349  loss_gen: 1.4640
# 08/10 06:59:14 - mmengine - INFO - Exp name: 20230810_064827
# 08/10 06:59:14 - mmengine - INFO - Epoch(train) [220][40/40]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:00  time: 0.0589  data_time: 0.0425  memory: 44  loss: 1.6040  loss_disc_fake: 0.5896  loss_disc_real: 0.6070  loss_gen: 1.6040
# 08/10 06:59:14 - mmengine - INFO - Saving checkpoint at 220 epochs
# GAN(
#   (data_preprocessor): ImgDataPreprocessor()
#   (generator): Generator(
#     (model): Sequential(
#       (0): Linear(in_features=100, out_features=128, bias=True)
#       (1): LeakyReLU(negative_slope=0.2, inplace=True)
#       (2): Linear(in_features=128, out_features=256, bias=True)
#       (3): BatchNorm1d(256, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#       (4): LeakyReLU(negative_slope=0.2, inplace=True)
#       (5): Linear(in_features=256, out_features=512, bias=True)
#       (6): BatchNorm1d(512, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#       (7): LeakyReLU(negative_slope=0.2, inplace=True)
#       (8): Linear(in_features=512, out_features=1024, bias=True)
#       (9): BatchNorm1d(1024, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#       (10): LeakyReLU(negative_slope=0.2, inplace=True)
#       (11): Linear(in_features=1024, out_features=784, bias=True)
#       (12): Tanh()
#     )
#   )
#   (discriminator): Discriminator(
#     (model): Sequential(
#       (0): Linear(in_features=784, out_features=512, bias=True)
#       (1): LeakyReLU(negative_slope=0.2, inplace=True)
#       (2): Linear(in_features=512, out_features=256, bias=True)
#       (3): LeakyReLU(negative_slope=0.2, inplace=True)
#       (4): Linear(in_features=256, out_features=1, bias=True)
#       (5): Sigmoid()
#     )
#   )
# )

# %%
#验证结果
z=torch.randn(64,100).cuda()
img=model(z)

from torchvision.utils import save_image
save_image(img,'work_dir/gan_result/result.jpg',normalize=True)
